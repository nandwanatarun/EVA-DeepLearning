# %%
# import the necessary packages
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
# Reading in the input image
image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F13EA0E6588>

# %%
edges = cv2.Canny(image,100,200)

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=400x364 at 0x7F13E1501EF0>

# %%
#Display verticle edges
#kernel = np.ones((3,3),np.float32)/25
#kernel = np.float32([[-1,2,-1],[-1,2,-1],[-1,2,-1]])
kernel=np.float32([[-1,0,1],[-1,0,1],[-1,0,1]])
#print(kernel)
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F13E1516588>

# %%
#Display horizontal edges
#kernel = np.float32([[-1,-1,-1],[2,2,2],[-1,-1,-1]])
kernel=np.float32([[-1,0,-1],[-1,0,-1],[1,1,1]])
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F13E150BBA8>

# %%
#Display 45 degree lines
#kernel = np.ones((3,3),np.float32)/25
#kernel = np.float32([[-1,-1,2],[-1,2,-1],[2,-1,-1]])
kernel=np.float32([[-1,0,1],[-1,1,0],[1,0,-1]])
#print(kernel)
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F13E150BB38>

# %%
# blur with 3X3 Kernel
kernel = np.float32([[0.11111111,0.11111111,0.11111111],[0.11111111,0.11111111,0.11111111],[0.11111111,0.11111111,0.11111111]])
#print(kernel)
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FC2B1BA7748>

# %%
# Sharp Image
kernel = np.array([[-1,-1,-1],[-1, 9,-1],[-1,-1,-1]])
#print(kernel)
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FC2B1BA7208>

# %%
# Identity function (doesn't do anything)
kernel = np.float32([[0,0,0],[0,1,0],[0,0,0]])
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FC2B1BA7208>
